# %% [markdown]
# # Lab 1
#
# __Objectives:__
#
# 1. Introduce the concept of a data repository,
#
# 2. Introduce pupular data repositories,
#
# 3. Extracting data from databases
#
# 4. Exploratory Data Analysis

# %% [markdown]
# ## Data Repositories
#
# For your final project you need data. You can find good data sources online. The two most popular online sources are:
#
# 1. Data repositories: These are websites where people upload datasets for various purposes.
#
# 2. Data competition sites: Platforms where you can access datasets for data science competitions.

# %% [markdown]
# ## Data Source
#
# Here are some websites you can collect your data from:
#
#
# 1. [The UC Irvine Machine Learning Repository](https://archive.ics.uci.edu)
#
# 2. [The Harvard Dataverse](https://dataverse.harvard.edu/)
#
# 3. [FiveThirtyEight](https://github.com/fivethirtyeight/)
#
# 4. [NYtimes](https://github.com/nytimes)
#
# 5. [Kaggle](https://www.kaggle.com)
#
# 6. [The International Data Analysis Olympiad](https://idao.world/)
#
#
# Check out these links for a few minutes!

# %% [markdown]
# ## Data Extraction
# Let's see how you can use a repository to access data. Note that I'm not assuming you know any of these! So let me know if you have any questions.

# %% [markdown]
# ### Example 1
#
# Check this out:
#
# [How Baby Boomers Get High](https://fivethirtyeight.com/features/how-baby-boomers-get-high/)
#
#
# 1. Go to the link associated with the data file https://github.com/fivethirtyeight/data/blob/master/drug-use-by-age/drug-use-by-age.csv
#
# 2. Click on the `Raw` button above the data table on the page.
# 3. Save the file as `drug-use-by-age.csv`, and upload it to Google Colab
# 4. Run the code chunks below.

# %%
import pandas as pd

# %%
data = pd.read_csv("drug-use-by-age.csv")

# %%
print(data)
# Out:
#       age     n  alcohol_use  alcohol_frequency  marijuana_use  \
# 0      12  2798          3.9                3.0            1.1
# 1      13  2757          8.5                6.0            3.4
# 2      14  2792         18.1                5.0            8.7
# 3      15  2956         29.2                6.0           14.5
# 4      16  3058         40.1               10.0           22.5
# 5      17  3038         49.3               13.0           28.0
# 6      18  2469         58.7               24.0           33.7
# 7      19  2223         64.6               36.0           33.4
# 8      20  2271         69.7               48.0           34.0
# 9      21  2354         83.2               52.0           33.0
# 10  22-23  4707         84.2               52.0           28.4
# 11  24-25  4591         83.1               52.0           24.9
# 12  26-29  2628         80.7               52.0           20.8
# 13  30-34  2864         77.5               52.0           16.4
# 14  35-49  7391         75.0               52.0           10.4
# 15  50-64  3923         67.2               52.0            7.3
# 16    65+  2448         49.3               52.0            1.2
#
#     marijuana_frequency  cocaine_use cocaine_frequency  crack_use  \
# 0                   4.0          0.1               5.0        0.0
# 1                  15.0          0.1               1.0        0.0
# 2                  24.0          0.1               5.5        0.0
# 3                  25.0          0.5               4.0        0.1
# 4                  30.0          1.0               7.0        0.0
# 5                  36.0          2.0               5.0        0.1
# 6                  52.0          3.2               5.0        0.4
# 7                  60.0          4.1               5.5        0.5
# 8                  60.0          4.9               8.0        0.6
# 9                  52.0          4.8               5.0        0.5
# 10                 52.0          4.5               5.0        0.5
# 11                 60.0          4.0               6.0        0.5
# 12                 52.0          3.2               5.0        0.4
# 13                 72.0          2.1               8.0        0.5
# 14                 48.0          1.5              15.0        0.5
# 15                 52.0          0.9              36.0        0.4
# 16                 36.0          0.0                 -        0.0
#
#    crack_frequency  ...  oxycontin_use oxycontin_frequency  tranquilizer_use  \
# 0                -  ...            0.1                24.5               0.2
# 1              3.0  ...            0.1                41.0               0.3
# 2                -  ...            0.4                 4.5               0.9
# 3              9.5  ...            0.8                 3.0               2.0
# 4              1.0  ...            1.1                 4.0               2.4
# 5             21.0  ...            1.4                 6.0               3.5
# 6             10.0  ...            1.7                 7.0               4.9
# 7              2.0  ...            1.5                 7.5               4.2
# 8              5.0  ...            1.7                12.0               5.4
# 9             17.0  ...            1.3                13.5               3.9
# 10             5.0  ...            1.7                17.5               4.4
# 11             6.0  ...            1.3                20.0               4.3
# 12             6.0  ...            1.2                13.5               4.2
# 13            15.0  ...            0.9                46.0               3.6
# 14            48.0  ...            0.3                12.0               1.9
# 15            62.0  ...            0.4                 5.0               1.4
# 16               -  ...            0.0                   -               0.2
#
#     tranquilizer_frequency  stimulant_use stimulant_frequency  meth_use  \
# 0                     52.0            0.2                 2.0       0.0
# 1                     25.5            0.3                 4.0       0.1
# 2                      5.0            0.8                12.0       0.1
# 3                      4.5            1.5                 6.0       0.3
# 4                     11.0            1.8                 9.5       0.3
# 5                      7.0            2.8                 9.0       0.6
# 6                     12.0            3.0                 8.0       0.5
# 7                      4.5            3.3                 6.0       0.4
# 8                     10.0            4.0                12.0       0.9
# 9                      7.0            4.1                10.0       0.6
# 10                    12.0            3.6                10.0       0.6
# 11                    10.0            2.6                10.0       0.7
# 12                    10.0            2.3                 7.0       0.6
# 13                     8.0            1.4                12.0       0.4
# 14                     6.0            0.6                24.0       0.2
# 15                    10.0            0.3                24.0       0.2
# 16                     5.0            0.0               364.0       0.0
#
#     meth_frequency  sedative_use sedative_frequency
# 0                -           0.2               13.0
# 1              5.0           0.1               19.0
# 2             24.0           0.2               16.5
# 3             10.5           0.4               30.0
# 4             36.0           0.2                3.0
# 5             48.0           0.5                6.5
# 6             12.0           0.4               10.0
# 7            105.0           0.3                6.0
# 8             12.0           0.5                4.0
# 9              2.0           0.3                9.0
# 10            46.0           0.2               52.0
# 11            21.0           0.2               17.5
# 12            30.0           0.4                4.0
# 13            54.0           0.4               10.0
# 14           104.0           0.3               10.0
# 15            30.0           0.2              104.0
# 16               -           0.0               15.0
#
# [17 rows x 28 columns]

# %% [markdown]
# Let's look at the first 5 rows of our data

# %%
data.head()
# Out:
#   age     n  alcohol_use  alcohol_frequency  marijuana_use  \
# 0  12  2798          3.9                3.0            1.1
# 1  13  2757          8.5                6.0            3.4
# 2  14  2792         18.1                5.0            8.7
# 3  15  2956         29.2                6.0           14.5
# 4  16  3058         40.1               10.0           22.5
#
#    marijuana_frequency  cocaine_use cocaine_frequency  crack_use  \
# 0                  4.0          0.1               5.0        0.0
# 1                 15.0          0.1               1.0        0.0
# 2                 24.0          0.1               5.5        0.0
# 3                 25.0          0.5               4.0        0.1
# 4                 30.0          1.0               7.0        0.0
#
#   crack_frequency  ...  oxycontin_use oxycontin_frequency  tranquilizer_use  \
# 0               -  ...            0.1                24.5               0.2
# 1             3.0  ...            0.1                41.0               0.3
# 2               -  ...            0.4                 4.5               0.9
# 3             9.5  ...            0.8                 3.0               2.0
# 4             1.0  ...            1.1                 4.0               2.4
#
#    tranquilizer_frequency  stimulant_use stimulant_frequency  meth_use  \
# 0                    52.0            0.2                 2.0       0.0
# 1                    25.5            0.3                 4.0       0.1
# 2                     5.0            0.8                12.0       0.1
# 3                     4.5            1.5                 6.0       0.3
# 4                    11.0            1.8                 9.5       0.3
#
#    meth_frequency  sedative_use sedative_frequency
# 0               -           0.2               13.0
# 1             5.0           0.1               19.0
# 2            24.0           0.2               16.5
# 3            10.5           0.4               30.0
# 4            36.0           0.2                3.0
#
# [5 rows x 28 columns]

# %%
# Find the first 10 rows
# code here

print(data.iloc[:10])
# Out:
#   age     n  alcohol_use  alcohol_frequency  marijuana_use  \
# 0  12  2798          3.9                3.0            1.1
# 1  13  2757          8.5                6.0            3.4
# 2  14  2792         18.1                5.0            8.7
# 3  15  2956         29.2                6.0           14.5
# 4  16  3058         40.1               10.0           22.5
# 5  17  3038         49.3               13.0           28.0
# 6  18  2469         58.7               24.0           33.7
# 7  19  2223         64.6               36.0           33.4
# 8  20  2271         69.7               48.0           34.0
# 9  21  2354         83.2               52.0           33.0
#
#    marijuana_frequency  cocaine_use cocaine_frequency  crack_use  \
# 0                  4.0          0.1               5.0        0.0
# 1                 15.0          0.1               1.0        0.0
# 2                 24.0          0.1               5.5        0.0
# 3                 25.0          0.5               4.0        0.1
# 4                 30.0          1.0               7.0        0.0
# 5                 36.0          2.0               5.0        0.1
# 6                 52.0          3.2               5.0        0.4
# 7                 60.0          4.1               5.5        0.5
# 8                 60.0          4.9               8.0        0.6
# 9                 52.0          4.8               5.0        0.5
#
#   crack_frequency  ...  oxycontin_use oxycontin_frequency  tranquilizer_use  \
# 0               -  ...            0.1                24.5               0.2
# 1             3.0  ...            0.1                41.0               0.3
# 2               -  ...            0.4                 4.5               0.9
# 3             9.5  ...            0.8                 3.0               2.0
# 4             1.0  ...            1.1                 4.0               2.4
# 5            21.0  ...            1.4                 6.0               3.5
# 6            10.0  ...            1.7                 7.0               4.9
# 7             2.0  ...            1.5                 7.5               4.2
# 8             5.0  ...            1.7                12.0               5.4
# 9            17.0  ...            1.3                13.5               3.9
#
#    tranquilizer_frequency  stimulant_use stimulant_frequency  meth_use  \
# 0                    52.0            0.2                 2.0       0.0
# 1                    25.5            0.3                 4.0       0.1
# 2                     5.0            0.8                12.0       0.1
# 3                     4.5            1.5                 6.0       0.3
# 4                    11.0            1.8                 9.5       0.3
# 5                     7.0            2.8                 9.0       0.6
# 6                    12.0            3.0                 8.0       0.5
# 7                     4.5            3.3                 6.0       0.4
# 8                    10.0            4.0                12.0       0.9
# 9                     7.0            4.1                10.0       0.6
#
#    meth_frequency  sedative_use sedative_frequency
# 0               -           0.2               13.0
# 1             5.0           0.1               19.0
# 2            24.0           0.2               16.5
# 3            10.5           0.4               30.0
# 4            36.0           0.2                3.0
# 5            48.0           0.5                6.5
# 6            12.0           0.4               10.0
# 7           105.0           0.3                6.0
# 8            12.0           0.5                4.0
# 9             2.0           0.3                9.0
#
# [10 rows x 28 columns]

# %%
# Print the last 5 row?
# code here

print(data.iloc[-5:])
# Out:
#       age     n  alcohol_use  alcohol_frequency  marijuana_use  \
# 12  26-29  2628         80.7               52.0           20.8
# 13  30-34  2864         77.5               52.0           16.4
# 14  35-49  7391         75.0               52.0           10.4
# 15  50-64  3923         67.2               52.0            7.3
# 16    65+  2448         49.3               52.0            1.2
#
#     marijuana_frequency  cocaine_use cocaine_frequency  crack_use  \
# 12                 52.0          3.2               5.0        0.4
# 13                 72.0          2.1               8.0        0.5
# 14                 48.0          1.5              15.0        0.5
# 15                 52.0          0.9              36.0        0.4
# 16                 36.0          0.0                 -        0.0
#
#    crack_frequency  ...  oxycontin_use oxycontin_frequency  tranquilizer_use  \
# 12             6.0  ...            1.2                13.5               4.2
# 13            15.0  ...            0.9                46.0               3.6
# 14            48.0  ...            0.3                12.0               1.9
# 15            62.0  ...            0.4                 5.0               1.4
# 16               -  ...            0.0                   -               0.2
#
#     tranquilizer_frequency  stimulant_use stimulant_frequency  meth_use  \
# 12                    10.0            2.3                 7.0       0.6
# 13                     8.0            1.4                12.0       0.4
# 14                     6.0            0.6                24.0       0.2
# 15                    10.0            0.3                24.0       0.2
# 16                     5.0            0.0               364.0       0.0
#
#     meth_frequency  sedative_use sedative_frequency
# 12            30.0           0.4                4.0
# 13            54.0           0.4               10.0
# 14           104.0           0.3               10.0
# 15            30.0           0.2              104.0
# 16               -           0.0               15.0
#
# [5 rows x 28 columns]

# %%
# Print the first 10 entry?
#code here

print(data.iloc[:10])
# Out:
#   age     n  alcohol_use  alcohol_frequency  marijuana_use  \
# 0  12  2798          3.9                3.0            1.1
# 1  13  2757          8.5                6.0            3.4
# 2  14  2792         18.1                5.0            8.7
# 3  15  2956         29.2                6.0           14.5
# 4  16  3058         40.1               10.0           22.5
# 5  17  3038         49.3               13.0           28.0
# 6  18  2469         58.7               24.0           33.7
# 7  19  2223         64.6               36.0           33.4
# 8  20  2271         69.7               48.0           34.0
# 9  21  2354         83.2               52.0           33.0
#
#    marijuana_frequency  cocaine_use cocaine_frequency  crack_use  \
# 0                  4.0          0.1               5.0        0.0
# 1                 15.0          0.1               1.0        0.0
# 2                 24.0          0.1               5.5        0.0
# 3                 25.0          0.5               4.0        0.1
# 4                 30.0          1.0               7.0        0.0
# 5                 36.0          2.0               5.0        0.1
# 6                 52.0          3.2               5.0        0.4
# 7                 60.0          4.1               5.5        0.5
# 8                 60.0          4.9               8.0        0.6
# 9                 52.0          4.8               5.0        0.5
#
#   crack_frequency  ...  oxycontin_use oxycontin_frequency  tranquilizer_use  \
# 0               -  ...            0.1                24.5               0.2
# 1             3.0  ...            0.1                41.0               0.3
# 2               -  ...            0.4                 4.5               0.9
# 3             9.5  ...            0.8                 3.0               2.0
# 4             1.0  ...            1.1                 4.0               2.4
# 5            21.0  ...            1.4                 6.0               3.5
# 6            10.0  ...            1.7                 7.0               4.9
# 7             2.0  ...            1.5                 7.5               4.2
# 8             5.0  ...            1.7                12.0               5.4
# 9            17.0  ...            1.3                13.5               3.9
#
#    tranquilizer_frequency  stimulant_use stimulant_frequency  meth_use  \
# 0                    52.0            0.2                 2.0       0.0
# 1                    25.5            0.3                 4.0       0.1
# 2                     5.0            0.8                12.0       0.1
# 3                     4.5            1.5                 6.0       0.3
# 4                    11.0            1.8                 9.5       0.3
# 5                     7.0            2.8                 9.0       0.6
# 6                    12.0            3.0                 8.0       0.5
# 7                     4.5            3.3                 6.0       0.4
# 8                    10.0            4.0                12.0       0.9
# 9                     7.0            4.1                10.0       0.6
#
#    meth_frequency  sedative_use sedative_frequency
# 0               -           0.2               13.0
# 1             5.0           0.1               19.0
# 2            24.0           0.2               16.5
# 3            10.5           0.4               30.0
# 4            36.0           0.2                3.0
# 5            48.0           0.5                6.5
# 6            12.0           0.4               10.0
# 7           105.0           0.3                6.0
# 8            12.0           0.5                4.0
# 9             2.0           0.3                9.0
#
# [10 rows x 28 columns]

# %%
#check what the function data.sample()does. What happens if you toss a number inside those parentheses (as an argument)?

print(data.sample(2))
# Out:
#   age     n  alcohol_use  alcohol_frequency  marijuana_use  \
# 4  16  3058         40.1               10.0           22.5
# 7  19  2223         64.6               36.0           33.4
#
#    marijuana_frequency  cocaine_use cocaine_frequency  crack_use  \
# 4                 30.0          1.0               7.0        0.0
# 7                 60.0          4.1               5.5        0.5
#
#   crack_frequency  ...  oxycontin_use oxycontin_frequency  tranquilizer_use  \
# 4             1.0  ...            1.1                 4.0               2.4
# 7             2.0  ...            1.5                 7.5               4.2
#
#    tranquilizer_frequency  stimulant_use stimulant_frequency  meth_use  \
# 4                    11.0            1.8                 9.5       0.3
# 7                     4.5            3.3                 6.0       0.4
#
#    meth_frequency  sedative_use sedative_frequency
# 4            36.0           0.2                3.0
# 7           105.0           0.3                6.0
#
# [2 rows x 28 columns]

# %% [markdown]
# It samples N random rows from the panda data file

# %% [markdown]
# Lets have a overall look of the dataset, checking if there is any inconsistency in the Dataset.

# %%
print('Rows:',data.shape[0])
print('Columns:',data.shape[1])
# Out:
# Rows: 17
# Columns: 28

# %%
print('Columns (features)')
print()
print( data.columns.tolist())
# Out:
# Columns (features)
#
# ['age', 'n', 'alcohol_use', 'alcohol_frequency', 'marijuana_use', 'marijuana_frequency', 'cocaine_use', 'cocaine_frequency', 'crack_use', 'crack_frequency', 'heroin_use', 'heroin_frequency', 'hallucinogen_use', 'hallucinogen_frequency', 'inhalant_use', 'inhalant_frequency', 'pain_releiver_use', 'pain_releiver_frequency', 'oxycontin_use', 'oxycontin_frequency', 'tranquilizer_use', 'tranquilizer_frequency', 'stimulant_use', 'stimulant_frequency', 'meth_use', 'meth_frequency', 'sedative_use', 'sedative_frequency']

# %%
print(' Unique Values')
print()
print( data.nunique())
# Out:
#  Unique Values
#
# age                        17
# n                          17
# alcohol_use                16
# alcohol_frequency           9
# marijuana_use              17
# marijuana_frequency        10
# cocaine_use                14
# cocaine_frequency          10
# crack_use                   5
# crack_frequency            13
# heroin_use                  9
# heroin_frequency           17
# hallucinogen_use           16
# hallucinogen_frequency      6
# inhalant_use               15
# inhalant_frequency         11
# pain_releiver_use          15
# pain_releiver_frequency    10
# oxycontin_use              12
# oxycontin_frequency        15
# tranquilizer_use           15
# tranquilizer_frequency     10
# stimulant_use              16
# stimulant_frequency        11
# meth_use                    9
# meth_frequency             14
# sedative_use                6
# sedative_frequency         14
# dtype: int64

# %% [markdown]
# Here is another useful function:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      17 non-null     object
#  1   n                        17 non-null     int64
#  2   alcohol_use              17 non-null     float64
#  3   alcohol_frequency        17 non-null     float64
#  4   marijuana_use            17 non-null     float64
#  5   marijuana_frequency      17 non-null     float64
#  6   cocaine_use              17 non-null     float64
#  7   cocaine_frequency        17 non-null     object
#  8   crack_use                17 non-null     float64
#  9   crack_frequency          17 non-null     object
#  10  heroin_use               17 non-null     float64
#  11  heroin_frequency         17 non-null     object
#  12  hallucinogen_use         17 non-null     float64
#  13  hallucinogen_frequency   17 non-null     float64
#  14  inhalant_use             17 non-null     float64
#  15  inhalant_frequency       17 non-null     object
#  16  pain_releiver_use        17 non-null     float64
#  17  pain_releiver_frequency  17 non-null     float64
#  18  oxycontin_use            17 non-null     float64
#  19  oxycontin_frequency      17 non-null     object
#  20  tranquilizer_use         17 non-null     float64
#  21  tranquilizer_frequency   17 non-null     float64
#  22  stimulant_use            17 non-null     float64
#  23  stimulant_frequency      17 non-null     float64
#  24  meth_use                 17 non-null     float64
#  25  meth_frequency           17 non-null     object
#  26  sedative_use             17 non-null     float64
#  27  sedative_frequency       17 non-null     float64
# dtypes: float64(20), int64(1), object(7)
# memory usage: 3.8+ KB

# %% [markdown]
# We can also load the directly from the website by placing the raw csv file directly into `.read_csv`.

# %%
#Code here
data = pd.read_csv("LINK")

# %%
#Code here

# %% [markdown]
# Can you filter your table to have information only among people in the age range 20-50

# %%
#Code here
print(data[8:16])
# Out:
#       age     n  alcohol_use  alcohol_frequency  marijuana_use  \
# 8      20  2271         69.7               48.0           34.0
# 9      21  2354         83.2               52.0           33.0
# 10  22-23  4707         84.2               52.0           28.4
# 11  24-25  4591         83.1               52.0           24.9
# 12  26-29  2628         80.7               52.0           20.8
# 13  30-34  2864         77.5               52.0           16.4
# 14  35-49  7391         75.0               52.0           10.4
# 15  50-64  3923         67.2               52.0            7.3
#
#     marijuana_frequency  cocaine_use cocaine_frequency  crack_use  \
# 8                  60.0          4.9               8.0        0.6
# 9                  52.0          4.8               5.0        0.5
# 10                 52.0          4.5               5.0        0.5
# 11                 60.0          4.0               6.0        0.5
# 12                 52.0          3.2               5.0        0.4
# 13                 72.0          2.1               8.0        0.5
# 14                 48.0          1.5              15.0        0.5
# 15                 52.0          0.9              36.0        0.4
#
#    crack_frequency  ...  oxycontin_use oxycontin_frequency  tranquilizer_use  \
# 8              5.0  ...            1.7                12.0               5.4
# 9             17.0  ...            1.3                13.5               3.9
# 10             5.0  ...            1.7                17.5               4.4
# 11             6.0  ...            1.3                20.0               4.3
# 12             6.0  ...            1.2                13.5               4.2
# 13            15.0  ...            0.9                46.0               3.6
# 14            48.0  ...            0.3                12.0               1.9
# 15            62.0  ...            0.4                 5.0               1.4
#
#     tranquilizer_frequency  stimulant_use stimulant_frequency  meth_use  \
# 8                     10.0            4.0                12.0       0.9
# 9                      7.0            4.1                10.0       0.6
# 10                    12.0            3.6                10.0       0.6
# 11                    10.0            2.6                10.0       0.7
# 12                    10.0            2.3                 7.0       0.6
# 13                     8.0            1.4                12.0       0.4
# 14                     6.0            0.6                24.0       0.2
# 15                    10.0            0.3                24.0       0.2
#
#     meth_frequency  sedative_use sedative_frequency
# 8             12.0           0.5                4.0
# 9              2.0           0.3                9.0
# 10            46.0           0.2               52.0
# 11            21.0           0.2               17.5
# 12            30.0           0.4                4.0
# 13            54.0           0.4               10.0
# 14           104.0           0.3               10.0
# 15            30.0           0.2              104.0
#
# [8 rows x 28 columns]

# %% [markdown]
# Let's plot this new table using scatter matrix.

# %%
#Code here
print(pd.plotting.scatter_matrix(data))
# Out:
# [[<Axes: xlabel='n', ylabel='n'> <Axes: xlabel='alcohol_use', ylabel='n'>
#   <Axes: xlabel='alcohol_frequency', ylabel='n'>
#   <Axes: xlabel='marijuana_use', ylabel='n'>
#   <Axes: xlabel='marijuana_frequency', ylabel='n'>
#   <Axes: xlabel='cocaine_use', ylabel='n'>
#   <Axes: xlabel='crack_use', ylabel='n'>
#   <Axes: xlabel='heroin_use', ylabel='n'>
#   <Axes: xlabel='hallucinogen_use', ylabel='n'>
#   <Axes: xlabel='hallucinogen_frequency', ylabel='n'>
#   <Axes: xlabel='inhalant_use', ylabel='n'>
#   <Axes: xlabel='pain_releiver_use', ylabel='n'>
#   <Axes: xlabel='pain_releiver_frequency', ylabel='n'>
#   <Axes: xlabel='oxycontin_use', ylabel='n'>
#   <Axes: xlabel='tranquilizer_use', ylabel='n'>
#   <Axes: xlabel='tranquilizer_frequency', ylabel='n'>
#   <Axes: xlabel='stimulant_use', ylabel='n'>
#   <Axes: xlabel='stimulant_frequency', ylabel='n'>
#   <Axes: xlabel='meth_use', ylabel='n'>
#   <Axes: xlabel='sedative_use', ylabel='n'>
#   <Axes: xlabel='sedative_frequency', ylabel='n'>]
#  [<Axes: xlabel='n', ylabel='alcohol_use'>
#   <Axes: xlabel='alcohol_use', ylabel='alcohol_use'>
#   <Axes: xlabel='alcohol_frequency', ylabel='alcohol_use'>
#   <Axes: xlabel='marijuana_use', ylabel='alcohol_use'>
#   <Axes: xlabel='marijuana_frequency', ylabel='alcohol_use'>
#   <Axes: xlabel='cocaine_use', ylabel='alcohol_use'>
#   <Axes: xlabel='crack_use', ylabel='alcohol_use'>
#   <Axes: xlabel='heroin_use', ylabel='alcohol_use'>
#   <Axes: xlabel='hallucinogen_use', ylabel='alcohol_use'>
#   <Axes: xlabel='hallucinogen_frequency', ylabel='alcohol_use'>
#   <Axes: xlabel='inhalant_use', ylabel='alcohol_use'>
#   <Axes: xlabel='pain_releiver_use', ylabel='alcohol_use'>
#   <Axes: xlabel='pain_releiver_frequency', ylabel='alcohol_use'>
#   <Axes: xlabel='oxycontin_use', ylabel='alcohol_use'>
#   <Axes: xlabel='tranquilizer_use', ylabel='alcohol_use'>
#   <Axes: xlabel='tranquilizer_frequency', ylabel='alcohol_use'>
#   <Axes: xlabel='stimulant_use', ylabel='alcohol_use'>
#   <Axes: xlabel='stimulant_frequency', ylabel='alcohol_use'>
#   <Axes: xlabel='meth_use', ylabel='alcohol_use'>
#   <Axes: xlabel='sedative_use', ylabel='alcohol_use'>
#   <Axes: xlabel='sedative_frequency', ylabel='alcohol_use'>]
#  [<Axes: xlabel='n', ylabel='alcohol_frequency'>
#   <Axes: xlabel='alcohol_use', ylabel='alcohol_frequency'>
#   <Axes: xlabel='alcohol_frequency', ylabel='alcohol_frequency'>
#   <Axes: xlabel='marijuana_use', ylabel='alcohol_frequency'>
#   <Axes: xlabel='marijuana_frequency', ylabel='alcohol_frequency'>
#   <Axes: xlabel='cocaine_use', ylabel='alcohol_frequency'>
#   <Axes: xlabel='crack_use', ylabel='alcohol_frequency'>
#   <Axes: xlabel='heroin_use', ylabel='alcohol_frequency'>
#   <Axes: xlabel='hallucinogen_use', ylabel='alcohol_frequency'>
#   <Axes: xlabel='hallucinogen_frequency', ylabel='alcohol_frequency'>
#   <Axes: xlabel='inhalant_use', ylabel='alcohol_frequency'>
#   <Axes: xlabel='pain_releiver_use', ylabel='alcohol_frequency'>
#   <Axes: xlabel='pain_releiver_frequency', ylabel='alcohol_frequency'>
#   <Axes: xlabel='oxycontin_use', ylabel='alcohol_frequency'>
#   <Axes: xlabel='tranquilizer_use', ylabel='alcohol_frequency'>
#   <Axes: xlabel='tranquilizer_frequency', ylabel='alcohol_frequency'>
#   <Axes: xlabel='stimulant_use', ylabel='alcohol_frequency'>
#   <Axes: xlabel='stimulant_frequency', ylabel='alcohol_frequency'>
#   <Axes: xlabel='meth_use', ylabel='alcohol_frequency'>
#   <Axes: xlabel='sedative_use', ylabel='alcohol_frequency'>
#   <Axes: xlabel='sedative_frequency', ylabel='alcohol_frequency'>]
#  [<Axes: xlabel='n', ylabel='marijuana_use'>
#   <Axes: xlabel='alcohol_use', ylabel='marijuana_use'>
#   <Axes: xlabel='alcohol_frequency', ylabel='marijuana_use'>
#   <Axes: xlabel='marijuana_use', ylabel='marijuana_use'>
#   <Axes: xlabel='marijuana_frequency', ylabel='marijuana_use'>
#   <Axes: xlabel='cocaine_use', ylabel='marijuana_use'>
#   <Axes: xlabel='crack_use', ylabel='marijuana_use'>
#   <Axes: xlabel='heroin_use', ylabel='marijuana_use'>
#   <Axes: xlabel='hallucinogen_use', ylabel='marijuana_use'>
#   <Axes: xlabel='hallucinogen_frequency', ylabel='marijuana_use'>
#   <Axes: xlabel='inhalant_use', ylabel='marijuana_use'>
#   <Axes: xlabel='pain_releiver_use', ylabel='marijuana_use'>
#   <Axes: xlabel='pain_releiver_frequency', ylabel='marijuana_use'>
#   <Axes: xlabel='oxycontin_use', ylabel='marijuana_use'>
#   <Axes: xlabel='tranquilizer_use', ylabel='marijuana_use'>
#   <Axes: xlabel='tranquilizer_frequency', ylabel='marijuana_use'>
#   <Axes: xlabel='stimulant_use', ylabel='marijuana_use'>
#   <Axes: xlabel='stimulant_frequency', ylabel='marijuana_use'>
#   <Axes: xlabel='meth_use', ylabel='marijuana_use'>
#   <Axes: xlabel='sedative_use', ylabel='marijuana_use'>
#   <Axes: xlabel='sedative_frequency', ylabel='marijuana_use'>]
#  [<Axes: xlabel='n', ylabel='marijuana_frequency'>
#   <Axes: xlabel='alcohol_use', ylabel='marijuana_frequency'>
#   <Axes: xlabel='alcohol_frequency', ylabel='marijuana_frequency'>
#   <Axes: xlabel='marijuana_use', ylabel='marijuana_frequency'>
#   <Axes: xlabel='marijuana_frequency', ylabel='marijuana_frequency'>
#   <Axes: xlabel='cocaine_use', ylabel='marijuana_frequency'>
#   <Axes: xlabel='crack_use', ylabel='marijuana_frequency'>
#   <Axes: xlabel='heroin_use', ylabel='marijuana_frequency'>
#   <Axes: xlabel='hallucinogen_use', ylabel='marijuana_frequency'>
#   <Axes: xlabel='hallucinogen_frequency', ylabel='marijuana_frequency'>
#   <Axes: xlabel='inhalant_use', ylabel='marijuana_frequency'>
#   <Axes: xlabel='pain_releiver_use', ylabel='marijuana_frequency'>
#   <Axes: xlabel='pain_releiver_frequency', ylabel='marijuana_frequency'>
#   <Axes: xlabel='oxycontin_use', ylabel='marijuana_frequency'>
#   <Axes: xlabel='tranquilizer_use', ylabel='marijuana_frequency'>
#   <Axes: xlabel='tranquilizer_frequency', ylabel='marijuana_frequency'>
#   <Axes: xlabel='stimulant_use', ylabel='marijuana_frequency'>
#   <Axes: xlabel='stimulant_frequency', ylabel='marijuana_frequency'>
#   <Axes: xlabel='meth_use', ylabel='marijuana_frequency'>
#   <Axes: xlabel='sedative_use', ylabel='marijuana_frequency'>
#   <Axes: xlabel='sedative_frequency', ylabel='marijuana_frequency'>]
#  [<Axes: xlabel='n', ylabel='cocaine_use'>
#   <Axes: xlabel='alcohol_use', ylabel='cocaine_use'>
#   <Axes: xlabel='alcohol_frequency', ylabel='cocaine_use'>
#   <Axes: xlabel='marijuana_use', ylabel='cocaine_use'>
#   <Axes: xlabel='marijuana_frequency', ylabel='cocaine_use'>
#   <Axes: xlabel='cocaine_use', ylabel='cocaine_use'>
#   <Axes: xlabel='crack_use', ylabel='cocaine_use'>
#   <Axes: xlabel='heroin_use', ylabel='cocaine_use'>
#   <Axes: xlabel='hallucinogen_use', ylabel='cocaine_use'>
#   <Axes: xlabel='hallucinogen_frequency', ylabel='cocaine_use'>
#   <Axes: xlabel='inhalant_use', ylabel='cocaine_use'>
#   <Axes: xlabel='pain_releiver_use', ylabel='cocaine_use'>
#   <Axes: xlabel='pain_releiver_frequency', ylabel='cocaine_use'>
#   <Axes: xlabel='oxycontin_use', ylabel='cocaine_use'>
#   <Axes: xlabel='tranquilizer_use', ylabel='cocaine_use'>
#   <Axes: xlabel='tranquilizer_frequency', ylabel='cocaine_use'>
#   <Axes: xlabel='stimulant_use', ylabel='cocaine_use'>
#   <Axes: xlabel='stimulant_frequency', ylabel='cocaine_use'>
#   <Axes: xlabel='meth_use', ylabel='cocaine_use'>
#   <Axes: xlabel='sedative_use', ylabel='cocaine_use'>
#   <Axes: xlabel='sedative_frequency', ylabel='cocaine_use'>]
#  [<Axes: xlabel='n', ylabel='crack_use'>
#   <Axes: xlabel='alcohol_use', ylabel='crack_use'>
#   <Axes: xlabel='alcohol_frequency', ylabel='crack_use'>
#   <Axes: xlabel='marijuana_use', ylabel='crack_use'>
#   <Axes: xlabel='marijuana_frequency', ylabel='crack_use'>
#   <Axes: xlabel='cocaine_use', ylabel='crack_use'>
#   <Axes: xlabel='crack_use', ylabel='crack_use'>
#   <Axes: xlabel='heroin_use', ylabel='crack_use'>
#   <Axes: xlabel='hallucinogen_use', ylabel='crack_use'>
#   <Axes: xlabel='hallucinogen_frequency', ylabel='crack_use'>
#   <Axes: xlabel='inhalant_use', ylabel='crack_use'>
#   <Axes: xlabel='pain_releiver_use', ylabel='crack_use'>
#   <Axes: xlabel='pain_releiver_frequency', ylabel='crack_use'>
#   <Axes: xlabel='oxycontin_use', ylabel='crack_use'>
#   <Axes: xlabel='tranquilizer_use', ylabel='crack_use'>
#   <Axes: xlabel='tranquilizer_frequency', ylabel='crack_use'>
#   <Axes: xlabel='stimulant_use', ylabel='crack_use'>
#   <Axes: xlabel='stimulant_frequency', ylabel='crack_use'>
#   <Axes: xlabel='meth_use', ylabel='crack_use'>
#   <Axes: xlabel='sedative_use', ylabel='crack_use'>
#   <Axes: xlabel='sedative_frequency', ylabel='crack_use'>]
#  [<Axes: xlabel='n', ylabel='heroin_use'>
#   <Axes: xlabel='alcohol_use', ylabel='heroin_use'>
#   <Axes: xlabel='alcohol_frequency', ylabel='heroin_use'>
#   <Axes: xlabel='marijuana_use', ylabel='heroin_use'>
#   <Axes: xlabel='marijuana_frequency', ylabel='heroin_use'>
#   <Axes: xlabel='cocaine_use', ylabel='heroin_use'>
#   <Axes: xlabel='crack_use', ylabel='heroin_use'>
#   <Axes: xlabel='heroin_use', ylabel='heroin_use'>
#   <Axes: xlabel='hallucinogen_use', ylabel='heroin_use'>
#   <Axes: xlabel='hallucinogen_frequency', ylabel='heroin_use'>
#   <Axes: xlabel='inhalant_use', ylabel='heroin_use'>
#   <Axes: xlabel='pain_releiver_use', ylabel='heroin_use'>
#   <Axes: xlabel='pain_releiver_frequency', ylabel='heroin_use'>
#   <Axes: xlabel='oxycontin_use', ylabel='heroin_use'>
#   <Axes: xlabel='tranquilizer_use', ylabel='heroin_use'>
#   <Axes: xlabel='tranquilizer_frequency', ylabel='heroin_use'>
#   <Axes: xlabel='stimulant_use', ylabel='heroin_use'>
#   <Axes: xlabel='stimulant_frequency', ylabel='heroin_use'>
#   <Axes: xlabel='meth_use', ylabel='heroin_use'>
#   <Axes: xlabel='sedative_use', ylabel='heroin_use'>
#   <Axes: xlabel='sedative_frequency', ylabel='heroin_use'>]
#  [<Axes: xlabel='n', ylabel='hallucinogen_use'>
#   <Axes: xlabel='alcohol_use', ylabel='hallucinogen_use'>
#   <Axes: xlabel='alcohol_frequency', ylabel='hallucinogen_use'>
#   <Axes: xlabel='marijuana_use', ylabel='hallucinogen_use'>
#   <Axes: xlabel='marijuana_frequency', ylabel='hallucinogen_use'>
#   <Axes: xlabel='cocaine_use', ylabel='hallucinogen_use'>
#   <Axes: xlabel='crack_use', ylabel='hallucinogen_use'>
#   <Axes: xlabel='heroin_use', ylabel='hallucinogen_use'>
#   <Axes: xlabel='hallucinogen_use', ylabel='hallucinogen_use'>
#   <Axes: xlabel='hallucinogen_frequency', ylabel='hallucinogen_use'>
#   <Axes: xlabel='inhalant_use', ylabel='hallucinogen_use'>
#   <Axes: xlabel='pain_releiver_use', ylabel='hallucinogen_use'>
#   <Axes: xlabel='pain_releiver_frequency', ylabel='hallucinogen_use'>
#   <Axes: xlabel='oxycontin_use', ylabel='hallucinogen_use'>
#   <Axes: xlabel='tranquilizer_use', ylabel='hallucinogen_use'>
#   <Axes: xlabel='tranquilizer_frequency', ylabel='hallucinogen_use'>
#   <Axes: xlabel='stimulant_use', ylabel='hallucinogen_use'>
#   <Axes: xlabel='stimulant_frequency', ylabel='hallucinogen_use'>
#   <Axes: xlabel='meth_use', ylabel='hallucinogen_use'>
#   <Axes: xlabel='sedative_use', ylabel='hallucinogen_use'>
#   <Axes: xlabel='sedative_frequency', ylabel='hallucinogen_use'>]
#  [<Axes: xlabel='n', ylabel='hallucinogen_frequency'>
#   <Axes: xlabel='alcohol_use', ylabel='hallucinogen_frequency'>
#   <Axes: xlabel='alcohol_frequency', ylabel='hallucinogen_frequency'>
#   <Axes: xlabel='marijuana_use', ylabel='hallucinogen_frequency'>
#   <Axes: xlabel='marijuana_frequency', ylabel='hallucinogen_frequency'>
#   <Axes: xlabel='cocaine_use', ylabel='hallucinogen_frequency'>
#   <Axes: xlabel='crack_use', ylabel='hallucinogen_frequency'>
#   <Axes: xlabel='heroin_use', ylabel='hallucinogen_frequency'>
#   <Axes: xlabel='hallucinogen_use', ylabel='hallucinogen_frequency'>
#   <Axes: xlabel='hallucinogen_frequency', ylabel='hallucinogen_frequency'>
#   <Axes: xlabel='inhalant_use', ylabel='hallucinogen_frequency'>
#   <Axes: xlabel='pain_releiver_use', ylabel='hallucinogen_frequency'>
#   <Axes: xlabel='pain_releiver_frequency', ylabel='hallucinogen_frequency'>
#   <Axes: xlabel='oxycontin_use', ylabel='hallucinogen_frequency'>
#   <Axes: xlabel='tranquilizer_use', ylabel='hallucinogen_frequency'>
#   <Axes: xlabel='tranquilizer_frequency', ylabel='hallucinogen_frequency'>
#   <Axes: xlabel='stimulant_use', ylabel='hallucinogen_frequency'>
#   <Axes: xlabel='stimulant_frequency', ylabel='hallucinogen_frequency'>
#   <Axes: xlabel='meth_use', ylabel='hallucinogen_frequency'>
#   <Axes: xlabel='sedative_use', ylabel='hallucinogen_frequency'>
#   <Axes: xlabel='sedative_frequency', ylabel='hallucinogen_frequency'>]
#  [<Axes: xlabel='n', ylabel='inhalant_use'>
#   <Axes: xlabel='alcohol_use', ylabel='inhalant_use'>
#   <Axes: xlabel='alcohol_frequency', ylabel='inhalant_use'>
#   <Axes: xlabel='marijuana_use', ylabel='inhalant_use'>
#   <Axes: xlabel='marijuana_frequency', ylabel='inhalant_use'>
#   <Axes: xlabel='cocaine_use', ylabel='inhalant_use'>
#   <Axes: xlabel='crack_use', ylabel='inhalant_use'>
#   <Axes: xlabel='heroin_use', ylabel='inhalant_use'>
#   <Axes: xlabel='hallucinogen_use', ylabel='inhalant_use'>
#   <Axes: xlabel='hallucinogen_frequency', ylabel='inhalant_use'>
#   <Axes: xlabel='inhalant_use', ylabel='inhalant_use'>
#   <Axes: xlabel='pain_releiver_use', ylabel='inhalant_use'>
#   <Axes: xlabel='pain_releiver_frequency', ylabel='inhalant_use'>
#   <Axes: xlabel='oxycontin_use', ylabel='inhalant_use'>
#   <Axes: xlabel='tranquilizer_use', ylabel='inhalant_use'>
#   <Axes: xlabel='tranquilizer_frequency', ylabel='inhalant_use'>
#   <Axes: xlabel='stimulant_use', ylabel='inhalant_use'>
#   <Axes: xlabel='stimulant_frequency', ylabel='inhalant_use'>
#   <Axes: xlabel='meth_use', ylabel='inhalant_use'>
#   <Axes: xlabel='sedative_use', ylabel='inhalant_use'>
#   <Axes: xlabel='sedative_frequency', ylabel='inhalant_use'>]
#  [<Axes: xlabel='n', ylabel='pain_releiver_use'>
#   <Axes: xlabel='alcohol_use', ylabel='pain_releiver_use'>
#   <Axes: xlabel='alcohol_frequency', ylabel='pain_releiver_use'>
#   <Axes: xlabel='marijuana_use', ylabel='pain_releiver_use'>
#   <Axes: xlabel='marijuana_frequency', ylabel='pain_releiver_use'>
#   <Axes: xlabel='cocaine_use', ylabel='pain_releiver_use'>
#   <Axes: xlabel='crack_use', ylabel='pain_releiver_use'>
#   <Axes: xlabel='heroin_use', ylabel='pain_releiver_use'>
#   <Axes: xlabel='hallucinogen_use', ylabel='pain_releiver_use'>
#   <Axes: xlabel='hallucinogen_frequency', ylabel='pain_releiver_use'>
#   <Axes: xlabel='inhalant_use', ylabel='pain_releiver_use'>
#   <Axes: xlabel='pain_releiver_use', ylabel='pain_releiver_use'>
#   <Axes: xlabel='pain_releiver_frequency', ylabel='pain_releiver_use'>
#   <Axes: xlabel='oxycontin_use', ylabel='pain_releiver_use'>
#   <Axes: xlabel='tranquilizer_use', ylabel='pain_releiver_use'>
#   <Axes: xlabel='tranquilizer_frequency', ylabel='pain_releiver_use'>
#   <Axes: xlabel='stimulant_use', ylabel='pain_releiver_use'>
#   <Axes: xlabel='stimulant_frequency', ylabel='pain_releiver_use'>
#   <Axes: xlabel='meth_use', ylabel='pain_releiver_use'>
#   <Axes: xlabel='sedative_use', ylabel='pain_releiver_use'>
#   <Axes: xlabel='sedative_frequency', ylabel='pain_releiver_use'>]
#  [<Axes: xlabel='n', ylabel='pain_releiver_frequency'>
#   <Axes: xlabel='alcohol_use', ylabel='pain_releiver_frequency'>
#   <Axes: xlabel='alcohol_frequency', ylabel='pain_releiver_frequency'>
#   <Axes: xlabel='marijuana_use', ylabel='pain_releiver_frequency'>
#   <Axes: xlabel='marijuana_frequency', ylabel='pain_releiver_frequency'>
#   <Axes: xlabel='cocaine_use', ylabel='pain_releiver_frequency'>
#   <Axes: xlabel='crack_use', ylabel='pain_releiver_frequency'>
#   <Axes: xlabel='heroin_use', ylabel='pain_releiver_frequency'>
#   <Axes: xlabel='hallucinogen_use', ylabel='pain_releiver_frequency'>
#   <Axes: xlabel='hallucinogen_frequency', ylabel='pain_releiver_frequency'>
#   <Axes: xlabel='inhalant_use', ylabel='pain_releiver_frequency'>
#   <Axes: xlabel='pain_releiver_use', ylabel='pain_releiver_frequency'>
#   <Axes: xlabel='pain_releiver_frequency', ylabel='pain_releiver_frequency'>
#   <Axes: xlabel='oxycontin_use', ylabel='pain_releiver_frequency'>
#   <Axes: xlabel='tranquilizer_use', ylabel='pain_releiver_frequency'>
#   <Axes: xlabel='tranquilizer_frequency', ylabel='pain_releiver_frequency'>
#   <Axes: xlabel='stimulant_use', ylabel='pain_releiver_frequency'>
#   <Axes: xlabel='stimulant_frequency', ylabel='pain_releiver_frequency'>
#   <Axes: xlabel='meth_use', ylabel='pain_releiver_frequency'>
#   <Axes: xlabel='sedative_use', ylabel='pain_releiver_frequency'>
#   <Axes: xlabel='sedative_frequency', ylabel='pain_releiver_frequency'>]
#  [<Axes: xlabel='n', ylabel='oxycontin_use'>
#   <Axes: xlabel='alcohol_use', ylabel='oxycontin_use'>
#   <Axes: xlabel='alcohol_frequency', ylabel='oxycontin_use'>
#   <Axes: xlabel='marijuana_use', ylabel='oxycontin_use'>
#   <Axes: xlabel='marijuana_frequency', ylabel='oxycontin_use'>
#   <Axes: xlabel='cocaine_use', ylabel='oxycontin_use'>
#   <Axes: xlabel='crack_use', ylabel='oxycontin_use'>
#   <Axes: xlabel='heroin_use', ylabel='oxycontin_use'>
#   <Axes: xlabel='hallucinogen_use', ylabel='oxycontin_use'>
#   <Axes: xlabel='hallucinogen_frequency', ylabel='oxycontin_use'>
#   <Axes: xlabel='inhalant_use', ylabel='oxycontin_use'>
#   <Axes: xlabel='pain_releiver_use', ylabel='oxycontin_use'>
#   <Axes: xlabel='pain_releiver_frequency', ylabel='oxycontin_use'>
#   <Axes: xlabel='oxycontin_use', ylabel='oxycontin_use'>
#   <Axes: xlabel='tranquilizer_use', ylabel='oxycontin_use'>
#   <Axes: xlabel='tranquilizer_frequency', ylabel='oxycontin_use'>
#   <Axes: xlabel='stimulant_use', ylabel='oxycontin_use'>
#   <Axes: xlabel='stimulant_frequency', ylabel='oxycontin_use'>
#   <Axes: xlabel='meth_use', ylabel='oxycontin_use'>
#   <Axes: xlabel='sedative_use', ylabel='oxycontin_use'>
#   <Axes: xlabel='sedative_frequency', ylabel='oxycontin_use'>]
#  [<Axes: xlabel='n', ylabel='tranquilizer_use'>
#   <Axes: xlabel='alcohol_use', ylabel='tranquilizer_use'>
#   <Axes: xlabel='alcohol_frequency', ylabel='tranquilizer_use'>
#   <Axes: xlabel='marijuana_use', ylabel='tranquilizer_use'>
#   <Axes: xlabel='marijuana_frequency', ylabel='tranquilizer_use'>
#   <Axes: xlabel='cocaine_use', ylabel='tranquilizer_use'>
#   <Axes: xlabel='crack_use', ylabel='tranquilizer_use'>
#   <Axes: xlabel='heroin_use', ylabel='tranquilizer_use'>
#   <Axes: xlabel='hallucinogen_use', ylabel='tranquilizer_use'>
#   <Axes: xlabel='hallucinogen_frequency', ylabel='tranquilizer_use'>
#   <Axes: xlabel='inhalant_use', ylabel='tranquilizer_use'>
#   <Axes: xlabel='pain_releiver_use', ylabel='tranquilizer_use'>
#   <Axes: xlabel='pain_releiver_frequency', ylabel='tranquilizer_use'>
#   <Axes: xlabel='oxycontin_use', ylabel='tranquilizer_use'>
#   <Axes: xlabel='tranquilizer_use', ylabel='tranquilizer_use'>
#   <Axes: xlabel='tranquilizer_frequency', ylabel='tranquilizer_use'>
#   <Axes: xlabel='stimulant_use', ylabel='tranquilizer_use'>
#   <Axes: xlabel='stimulant_frequency', ylabel='tranquilizer_use'>
#   <Axes: xlabel='meth_use', ylabel='tranquilizer_use'>
#   <Axes: xlabel='sedative_use', ylabel='tranquilizer_use'>
#   <Axes: xlabel='sedative_frequency', ylabel='tranquilizer_use'>]
#  [<Axes: xlabel='n', ylabel='tranquilizer_frequency'>
#   <Axes: xlabel='alcohol_use', ylabel='tranquilizer_frequency'>
#   <Axes: xlabel='alcohol_frequency', ylabel='tranquilizer_frequency'>
#   <Axes: xlabel='marijuana_use', ylabel='tranquilizer_frequency'>
#   <Axes: xlabel='marijuana_frequency', ylabel='tranquilizer_frequency'>
#   <Axes: xlabel='cocaine_use', ylabel='tranquilizer_frequency'>
#   <Axes: xlabel='crack_use', ylabel='tranquilizer_frequency'>
#   <Axes: xlabel='heroin_use', ylabel='tranquilizer_frequency'>
#   <Axes: xlabel='hallucinogen_use', ylabel='tranquilizer_frequency'>
#   <Axes: xlabel='hallucinogen_frequency', ylabel='tranquilizer_frequency'>
#   <Axes: xlabel='inhalant_use', ylabel='tranquilizer_frequency'>
#   <Axes: xlabel='pain_releiver_use', ylabel='tranquilizer_frequency'>
#   <Axes: xlabel='pain_releiver_frequency', ylabel='tranquilizer_frequency'>
#   <Axes: xlabel='oxycontin_use', ylabel='tranquilizer_frequency'>
#   <Axes: xlabel='tranquilizer_use', ylabel='tranquilizer_frequency'>
#   <Axes: xlabel='tranquilizer_frequency', ylabel='tranquilizer_frequency'>
#   <Axes: xlabel='stimulant_use', ylabel='tranquilizer_frequency'>
#   <Axes: xlabel='stimulant_frequency', ylabel='tranquilizer_frequency'>
#   <Axes: xlabel='meth_use', ylabel='tranquilizer_frequency'>
#   <Axes: xlabel='sedative_use', ylabel='tranquilizer_frequency'>
#   <Axes: xlabel='sedative_frequency', ylabel='tranquilizer_frequency'>]
#  [<Axes: xlabel='n', ylabel='stimulant_use'>
#   <Axes: xlabel='alcohol_use', ylabel='stimulant_use'>
#   <Axes: xlabel='alcohol_frequency', ylabel='stimulant_use'>
#   <Axes: xlabel='marijuana_use', ylabel='stimulant_use'>
#   <Axes: xlabel='marijuana_frequency', ylabel='stimulant_use'>
#   <Axes: xlabel='cocaine_use', ylabel='stimulant_use'>
#   <Axes: xlabel='crack_use', ylabel='stimulant_use'>
#   <Axes: xlabel='heroin_use', ylabel='stimulant_use'>
#   <Axes: xlabel='hallucinogen_use', ylabel='stimulant_use'>
#   <Axes: xlabel='hallucinogen_frequency', ylabel='stimulant_use'>
#   <Axes: xlabel='inhalant_use', ylabel='stimulant_use'>
#   <Axes: xlabel='pain_releiver_use', ylabel='stimulant_use'>
#   <Axes: xlabel='pain_releiver_frequency', ylabel='stimulant_use'>
#   <Axes: xlabel='oxycontin_use', ylabel='stimulant_use'>
#   <Axes: xlabel='tranquilizer_use', ylabel='stimulant_use'>
#   <Axes: xlabel='tranquilizer_frequency', ylabel='stimulant_use'>
#   <Axes: xlabel='stimulant_use', ylabel='stimulant_use'>
#   <Axes: xlabel='stimulant_frequency', ylabel='stimulant_use'>
#   <Axes: xlabel='meth_use', ylabel='stimulant_use'>
#   <Axes: xlabel='sedative_use', ylabel='stimulant_use'>
#   <Axes: xlabel='sedative_frequency', ylabel='stimulant_use'>]
#  [<Axes: xlabel='n', ylabel='stimulant_frequency'>
#   <Axes: xlabel='alcohol_use', ylabel='stimulant_frequency'>
#   <Axes: xlabel='alcohol_frequency', ylabel='stimulant_frequency'>
#   <Axes: xlabel='marijuana_use', ylabel='stimulant_frequency'>
#   <Axes: xlabel='marijuana_frequency', ylabel='stimulant_frequency'>
#   <Axes: xlabel='cocaine_use', ylabel='stimulant_frequency'>
#   <Axes: xlabel='crack_use', ylabel='stimulant_frequency'>
#   <Axes: xlabel='heroin_use', ylabel='stimulant_frequency'>
#   <Axes: xlabel='hallucinogen_use', ylabel='stimulant_frequency'>
#   <Axes: xlabel='hallucinogen_frequency', ylabel='stimulant_frequency'>
#   <Axes: xlabel='inhalant_use', ylabel='stimulant_frequency'>
#   <Axes: xlabel='pain_releiver_use', ylabel='stimulant_frequency'>
#   <Axes: xlabel='pain_releiver_frequency', ylabel='stimulant_frequency'>
#   <Axes: xlabel='oxycontin_use', ylabel='stimulant_frequency'>
#   <Axes: xlabel='tranquilizer_use', ylabel='stimulant_frequency'>
#   <Axes: xlabel='tranquilizer_frequency', ylabel='stimulant_frequency'>
#   <Axes: xlabel='stimulant_use', ylabel='stimulant_frequency'>
#   <Axes: xlabel='stimulant_frequency', ylabel='stimulant_frequency'>
#   <Axes: xlabel='meth_use', ylabel='stimulant_frequency'>
#   <Axes: xlabel='sedative_use', ylabel='stimulant_frequency'>
#   <Axes: xlabel='sedative_frequency', ylabel='stimulant_frequency'>]
#  [<Axes: xlabel='n', ylabel='meth_use'>
#   <Axes: xlabel='alcohol_use', ylabel='meth_use'>
#   <Axes: xlabel='alcohol_frequency', ylabel='meth_use'>
#   <Axes: xlabel='marijuana_use', ylabel='meth_use'>
#   <Axes: xlabel='marijuana_frequency', ylabel='meth_use'>
#   <Axes: xlabel='cocaine_use', ylabel='meth_use'>
#   <Axes: xlabel='crack_use', ylabel='meth_use'>
#   <Axes: xlabel='heroin_use', ylabel='meth_use'>
#   <Axes: xlabel='hallucinogen_use', ylabel='meth_use'>
#   <Axes: xlabel='hallucinogen_frequency', ylabel='meth_use'>
#   <Axes: xlabel='inhalant_use', ylabel='meth_use'>
#   <Axes: xlabel='pain_releiver_use', ylabel='meth_use'>
#   <Axes: xlabel='pain_releiver_frequency', ylabel='meth_use'>
#   <Axes: xlabel='oxycontin_use', ylabel='meth_use'>
#   <Axes: xlabel='tranquilizer_use', ylabel='meth_use'>
#   <Axes: xlabel='tranquilizer_frequency', ylabel='meth_use'>
#   <Axes: xlabel='stimulant_use', ylabel='meth_use'>
#   <Axes: xlabel='stimulant_frequency', ylabel='meth_use'>
#   <Axes: xlabel='meth_use', ylabel='meth_use'>
#   <Axes: xlabel='sedative_use', ylabel='meth_use'>
#   <Axes: xlabel='sedative_frequency', ylabel='meth_use'>]
#  [<Axes: xlabel='n', ylabel='sedative_use'>
#   <Axes: xlabel='alcohol_use', ylabel='sedative_use'>
#   <Axes: xlabel='alcohol_frequency', ylabel='sedative_use'>
#   <Axes: xlabel='marijuana_use', ylabel='sedative_use'>
#   <Axes: xlabel='marijuana_frequency', ylabel='sedative_use'>
#   <Axes: xlabel='cocaine_use', ylabel='sedative_use'>
#   <Axes: xlabel='crack_use', ylabel='sedative_use'>
#   <Axes: xlabel='heroin_use', ylabel='sedative_use'>
#   <Axes: xlabel='hallucinogen_use', ylabel='sedative_use'>
#   <Axes: xlabel='hallucinogen_frequency', ylabel='sedative_use'>
#   <Axes: xlabel='inhalant_use', ylabel='sedative_use'>
#   <Axes: xlabel='pain_releiver_use', ylabel='sedative_use'>
#   <Axes: xlabel='pain_releiver_frequency', ylabel='sedative_use'>
#   <Axes: xlabel='oxycontin_use', ylabel='sedative_use'>
#   <Axes: xlabel='tranquilizer_use', ylabel='sedative_use'>
#   <Axes: xlabel='tranquilizer_frequency', ylabel='sedative_use'>
#   <Axes: xlabel='stimulant_use', ylabel='sedative_use'>
#   <Axes: xlabel='stimulant_frequency', ylabel='sedative_use'>
#   <Axes: xlabel='meth_use', ylabel='sedative_use'>
#   <Axes: xlabel='sedative_use', ylabel='sedative_use'>
#   <Axes: xlabel='sedative_frequency', ylabel='sedative_use'>]
#  [<Axes: xlabel='n', ylabel='sedative_frequency'>
#   <Axes: xlabel='alcohol_use', ylabel='sedative_frequency'>
#   <Axes: xlabel='alcohol_frequency', ylabel='sedative_frequency'>
#   <Axes: xlabel='marijuana_use', ylabel='sedative_frequency'>
#   <Axes: xlabel='marijuana_frequency', ylabel='sedative_frequency'>
#   <Axes: xlabel='cocaine_use', ylabel='sedative_frequency'>
#   <Axes: xlabel='crack_use', ylabel='sedative_frequency'>
#   <Axes: xlabel='heroin_use', ylabel='sedative_frequency'>
#   <Axes: xlabel='hallucinogen_use', ylabel='sedative_frequency'>
#   <Axes: xlabel='hallucinogen_frequency', ylabel='sedative_frequency'>
#   <Axes: xlabel='inhalant_use', ylabel='sedative_frequency'>
#   <Axes: xlabel='pain_releiver_use', ylabel='sedative_frequency'>
#   <Axes: xlabel='pain_releiver_frequency', ylabel='sedative_frequency'>
#   <Axes: xlabel='oxycontin_use', ylabel='sedative_frequency'>
#   <Axes: xlabel='tranquilizer_use', ylabel='sedative_frequency'>
#   <Axes: xlabel='tranquilizer_frequency', ylabel='sedative_frequency'>
#   <Axes: xlabel='stimulant_use', ylabel='sedative_frequency'>
#   <Axes: xlabel='stimulant_frequency', ylabel='sedative_frequency'>
#   <Axes: xlabel='meth_use', ylabel='sedative_frequency'>
#   <Axes: xlabel='sedative_use', ylabel='sedative_frequency'>
#   <Axes: xlabel='sedative_frequency', ylabel='sedative_frequency'>]]

# %% [markdown]
# ### Example: Extracting Data from Kaggle.com
#
# Let's now show you how to grab some data from Kaggle.com. Heads up, __you'll need a Kaggle profile for this__.
#
# Kaggle has a whole section dedicated to public datasets, [here](https://www.kaggle.com/datasets). Today, we're downloading the famous iris dataset from [this link](https://www.kaggle.com/uciml/iris).
#
# #### Instructions
#
# 1. Go to this [link](https://www.kaggle.com/uciml/iris).
# 2. Download and unzip the zip file. Then upload the `Iris.csv` to Google Colab page.

# %%
#Read the Iris.csv file using pandas
data1 = pd.read_csv("Iris.csv")

# %%
#Examine the first five and the last five rows.
print(data1.iloc[:5])
print(data1.iloc[-5:])
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
#Examine a random sample
print(data1.sample(1))
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 120  121            6.9           3.2            5.7           2.3
#
#             Species
# 120  Iris-virginica

# %%
#Explor the data and check if there is any inconsistency in the Dataset.
print(data1.nunique())
# Out:
# Id               150
# SepalLengthCm     35
# SepalWidthCm      23
# PetalLengthCm     43
# PetalWidthCm      22
# Species            3
# dtype: int64

# %%
# you code

# %% [markdown]
# ## Exploratory Data Analysis
#
# Exploratory Data Analysis (EDA) is a critical step in data analysis that identifies general patterns and relations in the data.
#
#
# Lets start with the
# For example, we use scatter plots that show pairwise relationships between several variables.

# %% [markdown]
# Now lets try to plot the data and have some ideas about the relation between different columns.

# %%
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt


scatter_matrix(data, figsize=(14,14))
scatter_matrix(data1, figsize=(14,14))

plt.show()

# %% [markdown]
# When we're training algorithms, we need to pay attention to how many features we've got and how they relate to each other. If we've got a bunch of features that are all tangled up (correlated), using them all can mess with our accuracy. So, we've got to be smart about picking the right ones. But how?
#
# In machine learning and data analysis, understanding feature correlations is important because highly correlated features can sometimes provide redundant or overlapping information to algorithms, which can lead to suboptimal model performance. Therefore, feature selection or feature engineering techniques are used to choose the most relevant and uncorrelated features for modeling.
#
# __Correlation__ We say two or more features (variables) in a dataset are correlated if there is a statistical relationship or association between them. When features are correlated, changes in one feature may be related to changes in another.
#
# For example, if you have two features in a dataset, such as "temperature" and "ice cream sales," and you notice that as the temperature increases, ice cream sales also tend to increase, these two features can be considered correlated. In simpler terms, when one goes up, the other often goes up as well, or vice versa. In most data, pairwise correlations may not provide enough insights, and multivariate appraoches to exploratory data analyses are recommended.

# %%
# use .corr() to find pairwise correlation in CSV file of example 1

# %%
# run this code for a better view
import seaborn as sns
import pandas as pd


plt.figure(figsize=(10,8))

sns.heatmap(data.corr(), annot=True, cmap='cubehelix_r')
sns.heatmap(data1.corr(), annot=True, cmap='cubehelix_r')
plt.show()
# Out:
# <ipython-input-58-7647fe6fd27a>:8: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data1.corr(), annot=True, cmap='cubehelix_r')

# %% [markdown]
# Let's say your project focuses on only alcohol, marijuana and cocain. Create a table that specifically captures data on alcohol, marijuana, and cocaine.

# %%
# code here

AMC = data[["alcohol_use", "alcohol_frequency", "marijuana_use", "marijuana_frequency", "cocaine_use", "cocaine_frequency"]]
print(AMC)
# Out:
#     alcohol_use  alcohol_frequency  marijuana_use  marijuana_frequency  \
# 0           3.9                3.0            1.1                  4.0
# 1           8.5                6.0            3.4                 15.0
# 2          18.1                5.0            8.7                 24.0
# 3          29.2                6.0           14.5                 25.0
# 4          40.1               10.0           22.5                 30.0
# 5          49.3               13.0           28.0                 36.0
# 6          58.7               24.0           33.7                 52.0
# 7          64.6               36.0           33.4                 60.0
# 8          69.7               48.0           34.0                 60.0
# 9          83.2               52.0           33.0                 52.0
# 10         84.2               52.0           28.4                 52.0
# 11         83.1               52.0           24.9                 60.0
# 12         80.7               52.0           20.8                 52.0
# 13         77.5               52.0           16.4                 72.0
# 14         75.0               52.0           10.4                 48.0
# 15         67.2               52.0            7.3                 52.0
# 16         49.3               52.0            1.2                 36.0
#
#     cocaine_use cocaine_frequency
# 0           0.1               5.0
# 1           0.1               1.0
# 2           0.1               5.5
# 3           0.5               4.0
# 4           1.0               7.0
# 5           2.0               5.0
# 6           3.2               5.0
# 7           4.1               5.5
# 8           4.9               8.0
# 9           4.8               5.0
# 10          4.5               5.0
# 11          4.0               6.0
# 12          3.2               5.0
# 13          2.1               8.0
# 14          1.5              15.0
# 15          0.9              36.0
# 16          0.0                 -

# %%
# 1- Find the pariwise correlation in this new table.
import seaborn as sns

plt.figure(figsize=(10,8))

heatmap = sns.heatmap(AMC.corr(), annot=True, cmap='cubehelix_r')
plt.show()
# Out:
# <ipython-input-63-39ca3bc2dbaf>:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heatmap = sns.heatmap(AMC.corr(), annot=True, cmap='cubehelix_r')

# %%
# 2- Plot the heatmap as above

#Above in the code block above

# %%
# 3- How do you interpret the result?

#The numbers between 0 and 1 represent percentages that tell how likely one person is to use a substance if they consume another
#or how frequently one may use a certain substance if another is consumed.

# %%
# 4- plot data using scatter matrix


scatter_matrix(AMC, figsize=(14,14))
# Out:
# array([[<Axes: xlabel='alcohol_use', ylabel='alcohol_use'>,
#         <Axes: xlabel='alcohol_frequency', ylabel='alcohol_use'>,
#         <Axes: xlabel='marijuana_use', ylabel='alcohol_use'>,
#         <Axes: xlabel='marijuana_frequency', ylabel='alcohol_use'>,
#         <Axes: xlabel='cocaine_use', ylabel='alcohol_use'>],
#        [<Axes: xlabel='alcohol_use', ylabel='alcohol_frequency'>,
#         <Axes: xlabel='alcohol_frequency', ylabel='alcohol_frequency'>,
#         <Axes: xlabel='marijuana_use', ylabel='alcohol_frequency'>,
#         <Axes: xlabel='marijuana_frequency', ylabel='alcohol_frequency'>,
#         <Axes: xlabel='cocaine_use', ylabel='alcohol_frequency'>],
#        [<Axes: xlabel='alcohol_use', ylabel='marijuana_use'>,
#         <Axes: xlabel='alcohol_frequency', ylabel='marijuana_use'>,
#         <Axes: xlabel='marijuana_use', ylabel='marijuana_use'>,
#         <Axes: xlabel='marijuana_frequency', ylabel='marijuana_use'>,
#         <Axes: xlabel='cocaine_use', ylabel='marijuana_use'>],
#        [<Axes: xlabel='alcohol_use', ylabel='marijuana_frequency'>,
#         <Axes: xlabel='alcohol_frequency', ylabel='marijuana_frequency'>,
#         <Axes: xlabel='marijuana_use', ylabel='marijuana_frequency'>,
#         <Axes: xlabel='marijuana_frequency', ylabel='marijuana_frequency'>,
#         <Axes: xlabel='cocaine_use', ylabel='marijuana_frequency'>],
#        [<Axes: xlabel='alcohol_use', ylabel='cocaine_use'>,
#         <Axes: xlabel='alcohol_frequency', ylabel='cocaine_use'>,
#         <Axes: xlabel='marijuana_use', ylabel='cocaine_use'>,
#         <Axes: xlabel='marijuana_frequency', ylabel='cocaine_use'>,
#         <Axes: xlabel='cocaine_use', ylabel='cocaine_use'>]], dtype=object)

# %% [markdown]
# Let's try a different way of plotting: `sns.pairplot`. Check out its documentation to learn how to use it.
#
# Documentation link: [Seaborn pairplot documentation]( https://seaborn.pydata.org/generated/seaborn.pairplot.html)

# %%
#code her

sns.pairplot(AMC)

# %% [markdown]
# Follow the above steps for the CSV file in the second example.

# %%
# 1- Find the pariwise correlation in Iris.csv

import seaborn as sns

plt.figure(figsize=(10,8))

heatmap = sns.heatmap(data1.corr(), annot=True, cmap='cubehelix_r')
plt.show()
# Out:
# <ipython-input-70-218e775b5a09>:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heatmap = sns.heatmap(data1.corr(), annot=True, cmap='cubehelix_r')

# %%
# 2- Plot the heatmap as above
plt.show()

# %%
# 3- How do you interpret the result?

#Plants with a one certain feature have a certain likelihood (0 = 0% and 1 = 100%) to express a certain size for another plant part.

# %%
# 4- Plot data using scatter matrix

scatter_matrix(data1, figsize=(14,14))
# Out:
# array([[<Axes: xlabel='Id', ylabel='Id'>,
#         <Axes: xlabel='SepalLengthCm', ylabel='Id'>,
#         <Axes: xlabel='SepalWidthCm', ylabel='Id'>,
#         <Axes: xlabel='PetalLengthCm', ylabel='Id'>,
#         <Axes: xlabel='PetalWidthCm', ylabel='Id'>],
#        [<Axes: xlabel='Id', ylabel='SepalLengthCm'>,
#         <Axes: xlabel='SepalLengthCm', ylabel='SepalLengthCm'>,
#         <Axes: xlabel='SepalWidthCm', ylabel='SepalLengthCm'>,
#         <Axes: xlabel='PetalLengthCm', ylabel='SepalLengthCm'>,
#         <Axes: xlabel='PetalWidthCm', ylabel='SepalLengthCm'>],
#        [<Axes: xlabel='Id', ylabel='SepalWidthCm'>,
#         <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>,
#         <Axes: xlabel='SepalWidthCm', ylabel='SepalWidthCm'>,
#         <Axes: xlabel='PetalLengthCm', ylabel='SepalWidthCm'>,
#         <Axes: xlabel='PetalWidthCm', ylabel='SepalWidthCm'>],
#        [<Axes: xlabel='Id', ylabel='PetalLengthCm'>,
#         <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>,
#         <Axes: xlabel='SepalWidthCm', ylabel='PetalLengthCm'>,
#         <Axes: xlabel='PetalLengthCm', ylabel='PetalLengthCm'>,
#         <Axes: xlabel='PetalWidthCm', ylabel='PetalLengthCm'>],
#        [<Axes: xlabel='Id', ylabel='PetalWidthCm'>,
#         <Axes: xlabel='SepalLengthCm', ylabel='PetalWidthCm'>,
#         <Axes: xlabel='SepalWidthCm', ylabel='PetalWidthCm'>,
#         <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>,
#         <Axes: xlabel='PetalWidthCm', ylabel='PetalWidthCm'>]],
#       dtype=object)

# %%
# 5- Use sns.pairplot to plot data

sns.pairplot(data1)

# %% [markdown]
# Congratualtions! You finishied your first lab!
